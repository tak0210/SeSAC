# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load Data

# %%
# 데이터 로드 
df = pd.read_csv('/Users/jisupark_1/workspace/star_track_python/PRJ_Meteo/dataset/train_heat.csv')  # 실제 파일명으로 변경
# 컬럼명 정리 (train_heat. 접두사 제거)
df.columns = [col.replace('train_heat.', '') if 'train_heat.' in col else col for col in df.columns]

# %% [markdown]
# ### Data Exploration

# %%
print("=" * 60)
print("📊 기본 데이터 정보")
print("=" * 60)

# 1. 기본 정보
print(f"데이터 형태: {df.shape}")
print(f"컬럼 수: {len(df.columns)}")
print(f"행 수: {len(df)}")
print()

# 2. 컬럼 정보
print("컬럼 목록:")
print(df.columns.tolist())
print()

# 3. 데이터 타입
print("데이터 타입:")
print(df.dtypes)
print()

# 4. 기본 통계
print("기본 통계:")
print(df.describe())
print()

print("=" * 60)
print("🔍 결측치 분석")
print("=" * 60)

# 5. 결측치 현황 (전체)
print("전체 결측치 현황:")
missing_info = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100
missing_df = pd.DataFrame({
    '결측치_개수': missing_info,
    '결측치_비율(%)': missing_percent
})
print(missing_df[missing_df['결측치_개수'] > 0])
print()

# 6. -99 값 분석 (결측치로 표시된 값들)
print("-99로 표시된 결측치 분석:")
for col in df.columns:
    if df[col].dtype in ['int64', 'float64']:
        count_99 = (df[col] == -99).sum()
        if count_99 > 0:
            percent_99 = (count_99 / len(df)) * 100
            print(f"{col}: {count_99}개 ({percent_99:.2f}%)")
print()

# 7. 지사별 결측치 패턴
print("지사별 결측치 패턴:")
for branch in sorted(df['branch_id'].unique()):
    branch_data = df[df['branch_id'] == branch]
    print(f"\n지사 {branch} (총 {len(branch_data)}개 레코드):")
    
    for col in ['si', 'hm', 'ta', 'wd', 'ws', 'rn_day', 'rn_hr1', 'ta_chi']:
        if col in df.columns:
            # 일반 결측치
            missing_count = branch_data[col].isnull().sum()
            # -99 결측치  
            neg99_count = (branch_data[col] == -99).sum()
            total_missing = missing_count + neg99_count
            
            if total_missing > 0:
                missing_percent = (total_missing / len(branch_data)) * 100
                print(f"  {col}: {total_missing}개 ({missing_percent:.1f}%) [일반결측:{missing_count}, -99:{neg99_count}]")

print()

print("=" * 60)
print("📅 시간 데이터 분석")
print("=" * 60)

# 8. 시간 데이터 파싱 및 분석
df['datetime'] = pd.to_datetime(df['tm'], format='%Y%m%d%H', errors='coerce')
df['year'] = df['datetime'].dt.year
df['month'] = df['datetime'].dt.month
df['day'] = df['datetime'].dt.day
df['hour'] = df['datetime'].dt.hour

print("연도별 데이터 분포:")
print(df['year'].value_counts().sort_index())
print()

print("월별 데이터 분포:")
print(df['month'].value_counts().sort_index())
print()

print("시간별 데이터 분포:")
print(df['hour'].value_counts().sort_index())
print()

print("지사별 데이터 분포:")
print(df['branch_id'].value_counts().sort_index())
print()

print("=" * 60)
print("🌡️ 기상 데이터 범위 분석")
print("=" * 60)

# 9. 기상 변수 범위 확인
weather_vars = ['ta', 'wd', 'ws', 'rn_day', 'rn_hr1', 'hm', 'si', 'ta_chi']

for var in weather_vars:
    if var in df.columns:
        # -99 제외하고 분석
        clean_data = df[df[var] != -99][var].dropna()
        if len(clean_data) > 0:
            print(f"{var}:")
            print(f"  범위: {clean_data.min():.2f} ~ {clean_data.max():.2f}")
            print(f"  평균: {clean_data.mean():.2f}")
            print(f"  중앙값: {clean_data.median():.2f}")
            
            # 이상치 의심 값들
            Q1 = clean_data.quantile(0.25)
            Q3 = clean_data.quantile(0.75)
            IQR = Q3 - Q1
            outlier_low = Q1 - 1.5 * IQR
            outlier_high = Q3 + 1.5 * IQR
            outliers = clean_data[(clean_data < outlier_low) | (clean_data > outlier_high)]
            
            if len(outliers) > 0:
                print(f"  이상치 의심: {len(outliers)}개 ({len(outliers)/len(clean_data)*100:.1f}%)")
            print()

print("=" * 60)
print("🔥 열수요 데이터 분석")
print("=" * 60)

# 10. 열수요 기본 통계
print("열수요 기본 통계:")
print(f"범위: {df['heat_demand'].min():.1f} ~ {df['heat_demand'].max():.1f} Gcal/h")
print(f"평균: {df['heat_demand'].mean():.1f} Gcal/h")
print(f"중앙값: {df['heat_demand'].median():.1f} Gcal/h")
print(f"표준편차: {df['heat_demand'].std():.1f} Gcal/h")
print()

# 11. 지사별 열수요 특성
print("지사별 열수요 특성:")
branch_stats = df.groupby('branch_id')['heat_demand'].agg([
    'count', 'mean', 'std', 'min', 'max'
]).round(1)
print(branch_stats)
print()

# 12. 월별 열수요 패턴
print("월별 평균 열수요:")
monthly_demand = df.groupby('month')['heat_demand'].mean().round(1)
print(monthly_demand)
print()

# 13. 시간별 열수요 패턴
print("시간별 평균 열수요:")
hourly_demand = df.groupby('hour')['heat_demand'].mean().round(1)
print(hourly_demand)
print()

print("=" * 60)
print("🔗 상관관계 분석")
print("=" * 60)

# 14. 기상변수와 열수요 간 상관관계
print("기상변수와 열수요 간 상관관계:")
correlation_vars = ['ta', 'wd', 'ws', 'rn_day', 'rn_hr1', 'hm', 'ta_chi', 'heat_demand']
available_vars = [var for var in correlation_vars if var in df.columns]

# -99 값을 NaN으로 처리 후 상관관계 계산
df_corr = df[available_vars].replace(-99, np.nan)
correlations = df_corr.corr()['heat_demand'].drop('heat_demand').sort_values(key=abs, ascending=False)
print(correlations.round(3))
print()

print("=" * 60)
print("📊 데이터 품질 체크")
print("=" * 60)

# 15. 중복 데이터 확인
duplicates = df.duplicated(subset=['tm', 'branch_id']).sum()
print(f"중복 레코드: {duplicates}개")

# 16. 시계열 연속성 확인
print("\n시계열 연속성 확인 (각 지사별):")
for branch in sorted(df['branch_id'].unique()):
    branch_data = df[df['branch_id'] == branch].sort_values('tm')
    if len(branch_data) > 1:
        # 시간 간격 확인
        branch_data['time_diff'] = branch_data['datetime'].diff()
        expected_interval = pd.Timedelta(hours=1)
        irregular_intervals = (branch_data['time_diff'] != expected_interval).sum() - 1  # 첫 번째는 항상 NaN
        print(f"지사 {branch}: {irregular_intervals}개 불규칙 간격")

print("\n✅ 데이터 탐색 완료!")
print("\n다음 단계를 위한 요약:")
print("- 주요 결측치가 있는 변수들을 확인했습니다")
print("- 각 지사별 데이터 특성을 파악했습니다")  
print("- 기상변수와 열수요 간 상관관계를 확인했습니다")
print("- 이제 결측치 처리 방법을 결정할 수 있습니다")
# Out:
# ============================================================
# 📊 기본 데이터 정보
# ============================================================
# 데이터 형태: (499301, 12)
# 컬럼 수: 12
# 행 수: 499301
#
# 컬럼 목록:
# ['Unnamed: 0', 'tm', 'branch_id', 'ta', 'wd', 'ws', 'rn_day', 'rn_hr1', 'hm', 'si', 'ta_chi', 'heat_demand']
#
# 데이터 타입:
# Unnamed: 0       int64
# tm               int64
# branch_id       object
# ta             float64
# wd             float64
# ws             float64
# rn_day         float64
# rn_hr1         float64
# hm             float64
# si             float64
# ta_chi         float64
# heat_demand      int64
# dtype: object
#
# 기본 통계:
#           Unnamed: 0            tm             ta             wd  \
# count  499301.000000  4.993010e+05  499301.000000  499301.000000
# mean   249651.000000  2.022067e+09      10.621007     194.322872
# std    144135.927716  8.172155e+05      20.878917     118.348853
# min         1.000000  2.021010e+09     -99.000000     -99.000000
# 25%    124826.000000  2.021100e+09       4.400000     105.000000
# 50%    249651.000000  2.022070e+09      14.200000     212.100000
# 75%    374476.000000  2.023040e+09      22.500000     294.300000
# max    499301.000000  2.023123e+09      37.800000     360.000000
#
#                   ws         rn_day         rn_hr1             hm  \
# count  499301.000000  499301.000000  499301.000000  499301.000000
# mean       -2.344705      -1.843207      -3.649492      53.024052
# std        19.161911      21.340679      19.082926      49.080340
# min       -99.000000     -99.000000     -99.000000     -99.000000
# 25%         0.500000       0.000000       0.000000      44.900000
# 50%         1.100000       0.000000       0.000000      64.700000
# 75%         2.000000       0.000000       0.000000      82.500000
# max        11.900000     326.500000      92.500000     100.000000
#
#                   si         ta_chi    heat_demand
# count  499301.000000  499301.000000  499301.000000
# mean      -45.600886      13.869692      95.861923
# std        49.938291      11.888126     115.269280
# min       -99.000000     -99.000000     -99.000000
# 25%       -99.000000       4.400000      25.000000
# 50%         0.000000      15.000000      55.000000
# 75%         0.960000      24.300000     116.000000
# max         3.920000      37.100000     966.000000
#
# ============================================================
# 🔍 결측치 분석
# ============================================================
# 전체 결측치 현황:
# Empty DataFrame
# Columns: [결측치_개수, 결측치_비율(%)]
# Index: []
#
# -99로 표시된 결측치 분석:
# ta: 12997개 (2.60%)
# wd: 18815개 (3.77%)
# ws: 18815개 (3.77%)
# rn_day: 18626개 (3.73%)
# rn_hr1: 19154개 (3.84%)
# hm: 39717개 (7.95%)
# si: 232922개 (46.65%)
# ta_chi: 20개 (0.00%)
# heat_demand: 23개 (0.00%)
#
# 지사별 결측치 패턴:
#
# 지사 A (총 26279개 레코드):
#   si: 11916개 (45.3%) [일반결측:0, -99:11916]
#   hm: 4개 (0.0%) [일반결측:0, -99:4]
#   ta: 4개 (0.0%) [일반결측:0, -99:4]
#   wd: 18개 (0.1%) [일반결측:0, -99:18]
#   ws: 18개 (0.1%) [일반결측:0, -99:18]
#   rn_day: 277개 (1.1%) [일반결측:0, -99:277]
#   rn_hr1: 281개 (1.1%) [일반결측:0, -99:281]
#
# 지사 B (총 26279개 레코드):
#   si: 11916개 (45.3%) [일반결측:0, -99:11916]
#   hm: 2697개 (10.3%) [일반결측:0, -99:2697]
#   ta: 212개 (0.8%) [일반결측:0, -99:212]
#   wd: 433개 (1.6%) [일반결측:0, -99:433]
#   ws: 433개 (1.6%) [일반결측:0, -99:433]
#   rn_day: 309개 (1.2%) [일반결측:0, -99:309]
#   rn_hr1: 332개 (1.3%) [일반결측:0, -99:332]
#
# 지사 C (총 26279개 레코드):
#   si: 11916개 (45.3%) [일반결측:0, -99:11916]
#   hm: 23개 (0.1%) [일반결측:0, -99:23]
#   ta: 23개 (0.1%) [일반결측:0, -99:23]
#   wd: 182개 (0.7%) [일반결측:0, -99:182]
#   ws: 182개 (0.7%) [일반결측:0, -99:182]
#   rn_day: 226개 (0.9%) [일반결측:0, -99:226]
#   rn_hr1: 239개 (0.9%) [일반결측:0, -99:239]
#
# 지사 D (총 26279개 레코드):
#   si: 11915개 (45.3%) [일반결측:0, -99:11915]
#   hm: 7698개 (29.3%) [일반결측:0, -99:7698]
#   ta: 3739개 (14.2%) [일반결측:0, -99:3739]
#   wd: 5680개 (21.6%) [일반결측:0, -99:5680]
#   ws: 5680개 (21.6%) [일반결측:0, -99:5680]
#   rn_day: 4064개 (15.5%) [일반결측:0, -99:4064]
#   rn_hr1: 4112개 (15.6%) [일반결측:0, -99:4112]
#   ta_chi: 1개 (0.0%) [일반결측:0, -99:1]
#
# 지사 E (총 26279개 레코드):
#   si: 11915개 (45.3%) [일반결측:0, -99:11915]
#   hm: 7698개 (29.3%) [일반결측:0, -99:7698]
#   ta: 3739개 (14.2%) [일반결측:0, -99:3739]
#   wd: 5680개 (21.6%) [일반결측:0, -99:5680]
#   ws: 5680개 (21.6%) [일반결측:0, -99:5680]
#   rn_day: 4064개 (15.5%) [일반결측:0, -99:4064]
#   rn_hr1: 4112개 (15.6%) [일반결측:0, -99:4112]
#   ta_chi: 1개 (0.0%) [일반결측:0, -99:1]
#
# 지사 F (총 26279개 레코드):
#   si: 11916개 (45.3%) [일반결측:0, -99:11916]
#   hm: 2924개 (11.1%) [일반결측:0, -99:2924]
#   ta: 2657개 (10.1%) [일반결측:0, -99:2657]
#   wd: 2710개 (10.3%) [일반결측:0, -99:2710]
#   ws: 2710개 (10.3%) [일반결측:0, -99:2710]
#   rn_day: 2919개 (11.1%) [일반결측:0, -99:2919]
#   rn_hr1: 2940개 (11.2%) [일반결측:0, -99:2940]
#   ta_chi: 9개 (0.0%) [일반결측:0, -99:9]
#
# 지사 G (총 26279개 레코드):
#   si: 11915개 (45.3%) [일반결측:0, -99:11915]
#   hm: 292개 (1.1%) [일반결측:0, -99:292]
#   ta: 121개 (0.5%) [일반결측:0, -99:121]
#   wd: 428개 (1.6%) [일반결측:0, -99:428]
#   ws: 428개 (1.6%) [일반결측:0, -99:428]
#   rn_day: 973개 (3.7%) [일반결측:0, -99:973]
#   rn_hr1: 1042개 (4.0%) [일반결측:0, -99:1042]
#
# 지사 H (총 26279개 레코드):
#   si: 11915개 (45.3%) [일반결측:0, -99:11915]
#   hm: 292개 (1.1%) [일반결측:0, -99:292]
#   ta: 121개 (0.5%) [일반결측:0, -99:121]
#   wd: 428개 (1.6%) [일반결측:0, -99:428]
#   ws: 428개 (1.6%) [일반결측:0, -99:428]
#   rn_day: 973개 (3.7%) [일반결측:0, -99:973]
#   rn_hr1: 1042개 (4.0%) [일반결측:0, -99:1042]
#
# 지사 I (총 26279개 레코드):
#   si: 11915개 (45.3%) [일반결측:0, -99:11915]
#   hm: 3716개 (14.1%) [일반결측:0, -99:3716]
#   ta: 70개 (0.3%) [일반결측:0, -99:70]
#   wd: 257개 (1.0%) [일반결측:0, -99:257]
#   ws: 257개 (1.0%) [일반결측:0, -99:257]
#   rn_day: 73개 (0.3%) [일반결측:0, -99:73]
#   rn_hr1: 91개 (0.3%) [일반결측:0, -99:91]
#
# 지사 J (총 26279개 레코드):
#   si: 11915개 (45.3%) [일반결측:0, -99:11915]
#   hm: 608개 (2.3%) [일반결측:0, -99:608]
#   ta: 517개 (2.0%) [일반결측:0, -99:517]
#   wd: 513개 (2.0%) [일반결측:0, -99:513]
#   ws: 513개 (2.0%) [일반결측:0, -99:513]
#   rn_day: 753개 (2.9%) [일반결측:0, -99:753]
#   rn_hr1: 774개 (2.9%) [일반결측:0, -99:774]
#
# 지사 K (총 26279개 레코드):
#   si: 11915개 (45.3%) [일반결측:0, -99:11915]
#   hm: 3259개 (12.4%) [일반결측:0, -99:3259]
#   ta: 755개 (2.9%) [일반결측:0, -99:755]
#   wd: 855개 (3.3%) [일반결측:0, -99:855]
#   ws: 855개 (3.3%) [일반결측:0, -99:855]
#   rn_day: 1077개 (4.1%) [일반결측:0, -99:1077]
#   rn_hr1: 1130개 (4.3%) [일반결측:0, -99:1130]
#
# 지사 L (총 26279개 레코드):
#   si: 11916개 (45.3%) [일반결측:0, -99:11916]
#   hm: 14개 (0.1%) [일반결측:0, -99:14]
#   ta: 15개 (0.1%) [일반결측:0, -99:15]
#   wd: 24개 (0.1%) [일반결측:0, -99:24]
#   ws: 24개 (0.1%) [일반결측:0, -99:24]
#   rn_day: 90개 (0.3%) [일반결측:0, -99:90]
#   rn_hr1: 93개 (0.4%) [일반결측:0, -99:93]
#
# 지사 M (총 26279개 레코드):
#   si: 11942개 (45.4%) [일반결측:0, -99:11942]
#   hm: 160개 (0.6%) [일반결측:0, -99:160]
#   ta: 149개 (0.6%) [일반결측:0, -99:149]
#   wd: 170개 (0.6%) [일반결측:0, -99:170]
#   ws: 170개 (0.6%) [일반결측:0, -99:170]
#   rn_day: 267개 (1.0%) [일반결측:0, -99:267]
#   rn_hr1: 272개 (1.0%) [일반결측:0, -99:272]
#
# 지사 N (총 26279개 레코드):
#   si: 11912개 (45.3%) [일반결측:0, -99:11912]
#   hm: 4820개 (18.3%) [일반결측:0, -99:4820]
#   ta: 18개 (0.1%) [일반결측:0, -99:18]
#   wd: 32개 (0.1%) [일반결측:0, -99:32]
#   ws: 32개 (0.1%) [일반결측:0, -99:32]
#   rn_day: 370개 (1.4%) [일반결측:0, -99:370]
#   rn_hr1: 383개 (1.5%) [일반결측:0, -99:383]
#
# 지사 O (총 26279개 레코드):
#   si: 11919개 (45.4%) [일반결측:0, -99:11919]
#   hm: 4개 (0.0%) [일반결측:0, -99:4]
#   ta: 5개 (0.0%) [일반결측:0, -99:5]
#   wd: 18개 (0.1%) [일반결측:0, -99:18]
#   ws: 18개 (0.1%) [일반결측:0, -99:18]
#   rn_day: 425개 (1.6%) [일반결측:0, -99:425]
#   rn_hr1: 436개 (1.7%) [일반결측:0, -99:436]
#
# 지사 P (총 26279개 레코드):
#   si: 21715개 (82.6%) [일반결측:0, -99:21715]
#   hm: 19개 (0.1%) [일반결측:0, -99:19]
#   ta: 22개 (0.1%) [일반결측:0, -99:22]
#   wd: 38개 (0.1%) [일반결측:0, -99:38]
#   ws: 38개 (0.1%) [일반결측:0, -99:38]
#   rn_day: 246개 (0.9%) [일반결측:0, -99:246]
#   rn_hr1: 253개 (1.0%) [일반결측:0, -99:253]
#
# 지사 Q (총 26279개 레코드):
#   si: 8507개 (32.4%) [일반결측:0, -99:8507]
#   hm: 4672개 (17.8%) [일반결측:0, -99:4672]
#   ta: 13개 (0.0%) [일반결측:0, -99:13]
#   wd: 39개 (0.1%) [일반결측:0, -99:39]
#   ws: 39개 (0.1%) [일반결측:0, -99:39]
#   rn_day: 186개 (0.7%) [일반결측:0, -99:186]
#   rn_hr1: 192개 (0.7%) [일반결측:0, -99:192]
#   ta_chi: 9개 (0.0%) [일반결측:0, -99:9]
#
# 지사 R (총 26279개 레코드):
#   si: 12027개 (45.8%) [일반결측:0, -99:12027]
#   hm: 31개 (0.1%) [일반결측:0, -99:31]
#   ta: 31개 (0.1%) [일반결측:0, -99:31]
#   wd: 57개 (0.2%) [일반결측:0, -99:57]
#   ws: 57개 (0.2%) [일반결측:0, -99:57]
#   rn_day: 436개 (1.7%) [일반결측:0, -99:436]
#   rn_hr1: 448개 (1.7%) [일반결측:0, -99:448]
#
# 지사 S (총 26279개 레코드):
#   si: 11915개 (45.3%) [일반결측:0, -99:11915]
#   hm: 786개 (3.0%) [일반결측:0, -99:786]
#   ta: 786개 (3.0%) [일반결측:0, -99:786]
#   wd: 1253개 (4.8%) [일반결측:0, -99:1253]
#   ws: 1253개 (4.8%) [일반결측:0, -99:1253]
#   rn_day: 898개 (3.4%) [일반결측:0, -99:898]
#   rn_hr1: 982개 (3.7%) [일반결측:0, -99:982]
#
# ============================================================
# 📅 시간 데이터 분석
# ============================================================
# 연도별 데이터 분포:
# year
# 2021    166421
# 2022    166440
# 2023    166440
# Name: count, dtype: int64
#
# 월별 데이터 분포:
# month
# 1     42389
# 2     38304
# 3     42408
# 4     41040
# 5     42408
# 6     41040
# 7     42408
# 8     42408
# 9     41040
# 10    42408
# 11    41040
# 12    42408
# Name: count, dtype: int64
#
# 시간별 데이터 분포:
# hour
# 0     20786
# 1     20805
# 2     20805
# 3     20805
# 4     20805
# 5     20805
# 6     20805
# 7     20805
# 8     20805
# 9     20805
# 10    20805
# 11    20805
# 12    20805
# 13    20805
# 14    20805
# 15    20805
# 16    20805
# 17    20805
# 18    20805
# 19    20805
# 20    20805
# 21    20805
# 22    20805
# 23    20805
# Name: count, dtype: int64
#
# 지사별 데이터 분포:
# branch_id
# A    26279
# B    26279
# C    26279
# D    26279
# E    26279
# F    26279
# G    26279
# H    26279
# I    26279
# J    26279
# K    26279
# L    26279
# M    26279
# N    26279
# O    26279
# P    26279
# Q    26279
# R    26279
# S    26279
# Name: count, dtype: int64
#
# ============================================================
# 🌡️ 기상 데이터 범위 분석
# ============================================================
# ta:
#   범위: -19.70 ~ 37.80
#   평균: 13.55
#   중앙값: 14.70
#
# wd:
#   범위: -9.90 ~ 360.00
#   평균: 205.81
#   중앙값: 220.80
#
# ws:
#   범위: 0.00 ~ 11.90
#   평균: 1.44
#   중앙값: 1.20
#   이상치 의심: 9847개 (2.0%)
#
# rn_day:
#   범위: 0.00 ~ 326.50
#   평균: 1.92
#   중앙값: 0.00
#   이상치 의심: 79686개 (16.6%)
#
# rn_hr1:
#   범위: 0.00 ~ 92.50
#   평균: 0.15
#   중앙값: 0.00
#   이상치 의심: 27994개 (5.8%)
#
# hm:
#   범위: 2.50 ~ 100.00
#   평균: 66.16
#   중앙값: 67.60
#
# si:
#   범위: 0.00 ~ 3.92
#   평균: 1.09
#   중앙값: 0.85
#
# ta_chi:
#   범위: -24.70 ~ 37.10
#   평균: 13.87
#   중앙값: 15.00
#
# ============================================================
# 🔥 열수요 데이터 분석
# ============================================================
# 열수요 기본 통계:
# 범위: -99.0 ~ 966.0 Gcal/h
# 평균: 95.9 Gcal/h
# 중앙값: 55.0 Gcal/h
# 표준편차: 115.3 Gcal/h
#
# 지사별 열수요 특성:
#            count   mean    std  min  max
# branch_id
# A          26279  106.9   92.7  -99  443
# B          26279  227.8  191.5    1  966
# C          26279  248.3  193.9   14  908
# D          26279  158.5  127.3  -99  659
# E          26279   58.3   40.6  -99  227
# F          26279   67.8   42.6  -99  257
# G          26279  205.5  162.3    6  779
# H          26279  135.0  114.0    4  546
# I          26279   77.4   56.4    2  275
# J          26279   85.8   54.6  -99  295
# K          26279   52.6   29.4  -99  171
# L          26279   24.8   19.9    1  107
# M          26279   36.3   27.8  -99  152
# N          26279   84.3   72.1    3  365
# O          26279   71.5   57.7  -99  317
# P          26279   98.6   65.8    0  326
# Q          26279   55.6   45.1    0  286
# R          26279   15.2    9.7    0   51
# S          26279   11.3    8.2  -99   93
#
# 월별 평균 열수요:
# month
# 1     217.3
# 2     184.7
# 3     117.9
# 4      70.3
# 5      48.9
# 6      39.6
# 7      40.0
# 8      37.3
# 9      35.8
# 10     55.3
# 11    110.0
# 12    197.8
# Name: heat_demand, dtype: float64
#
# 시간별 평균 열수요:
# hour
# 0     105.5
# 1      95.4
# 2      89.1
# 3      84.9
# 4      83.2
# 5      83.6
# 6      87.2
# 7      97.0
# 8     109.0
# 9     109.8
# 10    102.5
# 11     95.3
# 12     89.2
# 13     84.9
# 14     82.0
# 15     79.8
# 16     79.5
# 17     83.1
# 18     92.1
# 19    103.9
# 20    113.7
# 21    118.3
# 22    118.1
# 23    113.5
# Name: heat_demand, dtype: float64
#
# ============================================================
# 🔗 상관관계 분석
# ============================================================
# 기상변수와 열수요 간 상관관계:
# ta       -0.566
# ta_chi   -0.565
# hm       -0.202
# rn_day   -0.066
# ws       -0.053
# rn_hr1   -0.047
# wd        0.042
# Name: heat_demand, dtype: float64
#
# ============================================================
# 📊 데이터 품질 체크
# ============================================================
# 중복 레코드: 0개
#
# 시계열 연속성 확인 (각 지사별):
# 지사 A: 0개 불규칙 간격
# 지사 B: 0개 불규칙 간격
# 지사 C: 0개 불규칙 간격
# 지사 D: 0개 불규칙 간격
# 지사 E: 0개 불규칙 간격
# 지사 F: 0개 불규칙 간격
# 지사 G: 0개 불규칙 간격
# 지사 H: 0개 불규칙 간격
# 지사 I: 0개 불규칙 간격
# 지사 J: 0개 불규칙 간격
# 지사 K: 0개 불규칙 간격
# 지사 L: 0개 불규칙 간격
# 지사 M: 0개 불규칙 간격
# 지사 N: 0개 불규칙 간격
# 지사 O: 0개 불규칙 간격
# 지사 P: 0개 불규칙 간격
# 지사 Q: 0개 불규칙 간격
# 지사 R: 0개 불규칙 간격
# 지사 S: 0개 불규칙 간격
#
# ✅ 데이터 탐색 완료!
#
# 다음 단계를 위한 요약:
# - 주요 결측치가 있는 변수들을 확인했습니다
# - 각 지사별 데이터 특성을 파악했습니다
# - 기상변수와 열수요 간 상관관계를 확인했습니다
# - 이제 결측치 처리 방법을 결정할 수 있습니다
